# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreyRodin3007/sf_data_science/blob/main/Project_1_%D0%9D%D0%BE%D1%83%D1%82%D0%B1%D1%83%D0%BA_%D1%88%D0%B0%D0%B1%D0%BB%D0%BE%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %%
#ваш код здесь
data = pd.read_csv('/content/drive/MyDrive/dst-3.0_16_1_hh_database.csv', encoding='utf-8', sep=';')

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
#ваш код здесь
data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
#ваш код здесь
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
#ваш код здесь
data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
#ваш код здесь

def transform_education_apply(df):
    """
    Преобразует столбец "Образование и ВУЗ" в новый столбец "Образование" с четырьмя категориями
    с использованием apply() и lambda-функции. Улучшенная версия с обработкой ошибок.

    Args:
        df: DataFrame с исходными данными.

    Returns:
        DataFrame с добавленным столбцом "Образование" и удаленным столбцом "Образование и ВУЗ".
    """

    # Обработка пропущенных значений и нестандартных записей
    df['Образование'] = df['Образование и ВУЗ'].apply(lambda x: x.strip() if isinstance(x, str) else "Неизвестно")

    df['Образование'] = df['Образование'].apply(lambda x: ' '.join(x.split()[:2]).lower() if x != "Неизвестно" else "Неизвестно")


    # Упрощение категорий образования
    mapping = {
        'высшее образование': 'высшее',
        'неоконченное высшее образование': 'неоконченное высшее',
        'среднее специальное образование': 'среднее специальное',
        'среднее образование': 'среднее',
        'среднее профессиональное образование': 'среднее специальное' # Добавленное для корректности
    }
    df['Образование'] = df['Образование'].replace(mapping)

    # Проверка уникальных значений
    print(df['Образование'].unique())

    # Удаление исходного столбца
    df.drop(columns=['Образование и ВУЗ'], inplace=True)

    return df

data = pd.DataFrame(data)

data = transform_education_apply(data)
data.head()
# Out:
# ['неоконченное высшее' 'высшее' 'среднее специальное' 'среднее']
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
#ваш код здесь
def transform_gender_age(df):
    """
    Преобразует столбец "Пол, возраст" в два новых столбца: "Пол" и "Возраст".

    Args:
        df: DataFrame с исходными данными.

    Returns:
        DataFrame с добавленными столбцами "Пол" и "Возраст" и удаленным столбцом "Пол, возраст".
    """

    # Разделение строки на части
    df[['Пол_temp', 'Возраст_temp', 'Дата_рождения']] = df['Пол, возраст'].str.split(' , ', expand=True)


    # Обработка пола
    df['Пол'] = df['Пол_temp'].apply(lambda x: 'М' if 'мужчина' in x.lower() else 'Ж')

    # Обработка возраста (извлечение чисел)
    df['Возраст'] = df['Возраст_temp'].str.extract('(\d+)').astype(int)

    #Проверка на ошибки
    df['Возраст'] = df['Возраст'].fillna(0)

    # Проверка уникальных значений
    print(df['Пол'].unique())
    print(df['Возраст'].unique())

    # Удаление временных и исходного столбцов
    df.drop(columns=['Пол, возраст', 'Пол_temp', 'Возраст_temp', 'Дата_рождения'], inplace=True)

    return df

data = transform_gender_age(data)
data.head()
# Out:
# ['М' 'Ж']
# [ 39  60  36  38  26  29  46  34  35  59  27  21  31  37  30  33  42  32
#   23  28  25  24  43  53  49  44  48  54  22  20  40  62  72  45  41  61
#   50  58  57  52  56  18  19  51  16  47  71  63  55  64  68  17  73  66
#   65  77  67  69  76  70  14  15 100]
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %%
#ваш код здесь

def get_experience_in_months(experience_str):
    # Если строка пустая или содержит "не указано", возвращаем None
    if not isinstance(experience_str, str) or "не указано" in experience_str.lower():
        return None  # Возвращаем None (аналог NaN)

    # Инициализация месяцев и лет
    years = 0
    months = 0

    # Разделяем строку на слова
    words = experience_str.split()[:6]

    # Проходим по словам и ищем количество лет и месяцев
    for i in range(len(words)):
        if words[i] in ["лет", "года", "год"]:
            if i > 0 and words[i - 1].isdigit():
                years = int(words[i - 1])  # Сохраняем количество лет
        elif words[i] in ["месяцев", "месяца", "месяц"]:
            if i > 0 and words[i - 1].isdigit():
                months = int(words[i - 1])  # Сохраняем количество месяцев

    # Преобразуем опыт в месяцы
    total_months = (years * 12) + months
    return total_months

# Применяем функцию к столбцу "Опыт работы"
data['Опыт работы (месяц)'] = data['Опыт работы'].apply(get_experience_in_months)

# Удаляем старый столбец "Опыт работы"
data.drop(columns=['Опыт работы'], inplace=True)

data.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# 4  Москва , не готова к переезду , готова к коман...
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# ...

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
#ваш код здесь


# Предполагаем, что у нас есть DataFrame с названием data
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск',
                  'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь',
                  'Воронеж', 'Волгоград']

# Функция для определения города
def extract_city(value):
    parts = value.split(' , ')
    city = parts[0]
    if city == 'Москва':
        return 'Москва'
    elif city == 'Санкт-Петербург':
        return 'Санкт-Петербург'
    elif city in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'

# Функция для определения готовности к переезду
def is_ready_to_relocate(value):
    not_ready_keywords = ['не готов к переезду', 'не готова к переезду']
    return not any(keyword in value for keyword in not_ready_keywords)

# Функция для определения готовности к командировкам
def is_ready_for_business_trips(value):
    not_ready_keywords = ['не готов к командировкам', 'не готова к командировкам']
    return not any(keyword in value for keyword in not_ready_keywords)

# Применяем функции к DataFrame
data['Город'] = data['Город, переезд, командировки'].apply(extract_city)
data['Готовность к переезду'] = data['Город, переезд, командировки'].apply(is_ready_to_relocate)
data['Готовность к командировкам'] = data['Город, переезд, командировки'].apply(is_ready_for_business_trips)

# Удаляем ненужный столбец
data.drop(columns=['Город, переезд, командировки'], inplace=True)
data.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#                                            Занятость  \
# 0  частичная занятость, проектная работа, полная ...
# 1  частичная занятость, проектная работа, полная ...
# 2                                   полная занятость
# 3  частичная занятость, проектная работа, полная ...
# 4                                   полная занятость
#
#                                               График  \
# 0  гибкий график, полный день, сменный график, ва...
# 1  гибкий график, полный день, сменный график, уд...
# 2                                        полный день
# ...

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
#ваш код здесь

employment_categories = ['полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка']
work_schedule_categories = ['полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод']

# Функция для One Hot Encoding
def one_hot_encode(column, categories):
    # Инициализируем DataFrame с False
    one_hot_df = pd.DataFrame(False, index=column.index, columns=categories)
    for category in categories:
        one_hot_df[category] = column.str.contains(category, case=False, na=False)
    return one_hot_df

# Применяем One Hot Encoding к признакам "Занятость" и "График"
employment_encoded = one_hot_encode(data['Занятость'], employment_categories)
work_schedule_encoded = one_hot_encode(data['График'], work_schedule_categories)

# Объединяем полученные признаки с основным DataFrame
data = pd.concat([data, employment_encoded, work_schedule_encoded], axis=1)

# Удаляем исходные столбцы "Занятость" и "График"
data.drop(columns=['Занятость', 'График'], inplace=True)
data.head()
# Out:
#             ЗП                          Ищет работу на должность:  \
# 0   29000 руб.                            Системный администратор
# 1   40000 руб.                               Технический писатель
# 2   20000 руб.                                           Оператор
# 3  100000 руб.  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4  140000 руб.                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# 1    Временный трудовой коллектив
# 2                    ПАО Сбербанк
# 3                        OpenSoft
# 4                        Мармелад
#
#                        Последняя/нынешняя должность Обновление резюме  \
# 0                           Системный администратор  16.04.2019 15:59
# 1  Менеджер проекта, Аналитик, Технический писатель  12.04.2019 08:42
# 2                               Кассир-операционист  16.04.2019 08:35
# 3                               Инженер-программист  08.04.2019 14:23
# ...

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
#ваш код здесь

# Прочитаем данные
data_exchange_rates = pd.read_csv('/content/drive/MyDrive/ExchangeRates.csv')
currency_table = {
    'Наименование валюты в данных': ['грн', 'USD', 'EUR', 'белруб', 'KGS', 'сум', 'AZN', 'KZT'],
    'Наименование валюты в ISO кодировке': ['UAH', 'USD', 'EUR', 'BYN', 'KGS', 'UZS', 'AZN', 'KZT'],
    'Пропорция': [10, 1, 1, 1, 10, 10000, 1, 100],
    'Расшифровка': ['гривна', 'доллар', 'евро', 'белорусский рубль', 'киргизский сом', 'узбекский сом', 'азербайджанский манат', 'казахстанский тенге']
}
df_currency_table = pd.DataFrame(currency_table)

# Подготовка даты
data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме'])
data['Дата обновления'] = data['Обновление резюме'].dt.date

# Функция, извлекающая элементы ЗП
def extract_salary_info(salary):
    amount, currency = salary.split()
    return pd.Series([int(amount), currency])

data[['amount', 'currency']] = data['ЗП'].apply(extract_salary_info)
data['currency'] = data['currency'].str.replace('.', '', regex=False)

# Создаем словарь для быстрого поиска ISO-кода по сокращению валюты
currency_map = dict(zip(df_currency_table['Наименование валюты в данных'], df_currency_table['Наименование валюты в ISO кодировке']))

# Преобразуем 'Дата обновления' в data_exchange_rates в datetime.date для корректного сравнения
data_exchange_rates['date'] = pd.to_datetime(data_exchange_rates['date']).dt.date

# Применяем словарь для преобразования сокращений валют в ISO-коды
data['currency'] = data['currency'].map(currency_map)

# Объединяем датафреймы для получения курса валюты
data = pd.merge(data, data_exchange_rates, left_on=['Дата обновления', 'currency'], right_on=['date', 'currency'], how='left')

# Обработка случаев, когда курс не найден (например, из-за несовпадения дат или валют)
data['close'] = data['close'].fillna(1) # Если курс не найден, принимаем, что это рубли.
data['proportion'] = data['proportion'].fillna(1) # Аналогично для proportion


# Расчет зарплаты в рублях
data['ЗП (руб)'] = (data['amount'] * data['close']) / data['proportion']

# Выбираем необходимые столбцы для результирующего датафрейма
result_columns = ['Ищет работу на должность:', 'Последнее/нынешнее место работы', 'Последняя/нынешняя должность', 'Обновление резюме', 'Авто', 'Образование', 'Пол', 'Возраст', 'Опыт работы (месяц)', 'Город', 'Готовность к переезду', 'Готовность к командировкам', 'полная занятость', 'частичная занятость', 'проектная работа', 'волонтерство', 'стажировка', 'полный день', 'сменный график', 'гибкий график', 'удаленная работа', 'вахтовый метод', 'ЗП (руб)']
data = data[result_columns]

data.head()
# Out:
# <ipython-input-137-ce792b9ca74b>:14: UserWarning: Parsing dates in %d.%m.%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data['Обновление резюме'] = pd.to_datetime(data['Обновление резюме'])
# <ipython-input-137-ce792b9ca74b>:29: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_exchange_rates['date'] = pd.to_datetime(data_exchange_rates['date']).dt.date
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#   Последнее/нынешнее место работы  \
# 0         МАОУ "СОШ № 1 г.Немана"
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Создание гистограммы и коробчатой диаграммы
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['Возраст'], kde=True)
plt.title('Гистограмма распределения возраста')
plt.xlabel('Возраст')
plt.ylabel('Частота')

plt.subplot(1, 2, 2)
sns.boxplot(y=data['Возраст'])
plt.title('Коробчатая диаграмма распределения возраста')
plt.ylabel('Возраст')


plt.tight_layout()
plt.show()


# Анализ распределения
# Мода (самое частое значение)
moda = data['Возраст'].mode()[0]

# Предельные значения
min_age = data['Возраст'].min()
max_age = data['Возраст'].max()

# Интервал, где находится большинство соискателей (например, интерквартильный размах)
q1 = data['Возраст'].quantile(0.25)
q3 = data['Возраст'].quantile(0.75)
iqr = q3 - q1
main_interval = (q1, q3)

# Аномалии (значения за пределами 1.5 IQR от границ интерквартильного размаха)
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = data[(data['Возраст'] < lower_bound) | (data['Возраст'] > upper_bound)]['Возраст']


print(f"Мода распределения возраста: {moda}")
print(f"Минимальный возраст: {min_age}")
print(f"Максимальный возраст: {max_age}")
print(f"Примерный интервал возраста большинства соискателей: {main_interval}")
print(f"Аномальные значения возраста: {outliers.values}")
# Out:
# Мода распределения возраста: 30
# Минимальный возраст: 14
# Максимальный возраст: 100
# Примерный интервал возраста большинства соискателей: (27.0, 36.0)
# Аномальные значения возраста: [60 59 53 ... 53 52 68]

# %% [markdown]
# ваши выводы по графику здесь
# * Мода распределения возраста: 30
# * Минимальный возраст: 14
# * Максимальный возраст: 100
# * Примерный интервал возраста большинства соискателей: (27.0, 36.0)
# * Аномальные значения возраста: [60 59 53 ... 53 52 68]
# * График распределения похож на нормальный

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь

# Создание гистограммы и коробчатой диаграммы
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['Опыт работы (месяц)'], kde=True)
plt.title('Гистограмма распределения опыта работы')
plt.xlabel('Опыт работы')
plt.ylabel('Частота')

plt.subplot(1, 2, 2)
sns.boxplot(y=data['Опыт работы (месяц)'])
plt.title('Коробчатая диаграмма распределения опыта работы')
plt.ylabel('Опыт работы')


plt.tight_layout()
plt.show()


# Анализ распределения
# Мода (самое частое значение)
moda = data['Опыт работы (месяц)'].mode()[0]

# Предельные значения
min_exp = data['Опыт работы (месяц)'].min()
max_exp = data['Опыт работы (месяц)'].max()

# Интервал, где находится большинство соискателей (например, интерквартильный размах)
q1 = data['Опыт работы (месяц)'].quantile(0.25)
q3 = data['Опыт работы (месяц)'].quantile(0.75)
iqr = q3 - q1
main_interval = (q1, q3)

# Аномалии (значения за пределами 1.5 IQR от границ интерквартильного размаха)
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = data[(data['Опыт работы (месяц)'] < lower_bound) | (data['Опыт работы (месяц)'] > upper_bound)]['Опыт работы (месяц)']


print(f"Мода распределения опыта работы: {moda}")
print(f"Минимальный опыт работы: {min_exp}")
print(f"Максимальный опыт работы: {max_exp}")
print(f"Примерный интервал опыта работы большинства соискателей: {main_interval}")
print(f"Аномальные значения опыта работы: {outliers.values}")
# Out:
# Мода распределения опыта работы: 81.0
# Минимальный опыт работы: 1.0
# Максимальный опыт работы: 1188.0
# Примерный интервал опыта работы большинства соискателей: (57.0, 154.0)
# Аномальные значения опыта работы: [510. 325. 303. ... 382. 379. 306.]

# %% [markdown]
# ваши выводы здесь
# * Мода распределения опыта работы: 81.0
# * Минимальный опыт работы: 1.0
# * Максимальный опыт работы: 1188.0
# * Примерный интервал опыта работы большинства соискателей: (57.0, 154.0)
# * Аномальные значения опыта работы: [510. 325. 303. ... 382. 379. 306.]

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака возраста? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# ваш код здесь
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(data['ЗП (руб)'], kde=False, bins=50)
plt.title('Гистограмма распределения зарплаты')
plt.xlabel('Зарплата (руб)')
plt.ylabel('Частота')

plt.subplot(1, 2, 2)
sns.boxplot(y=data['ЗП (руб)'])
plt.title('Коробчатая диаграмма распределения зарплаты')
plt.ylabel('Зарплата (руб)')

plt.tight_layout()
plt.show()


# Анализ распределения
min_salary = data['ЗП (руб)'].min()
max_salary = data['ЗП (руб)'].max()

q1 = data['ЗП (руб)'].quantile(0.25)
q3 = data['ЗП (руб)'].quantile(0.75)
iqr = q3 - q1
main_interval = (q1, q3)

lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = data[(data['ЗП (руб)'] < lower_bound) | (data['ЗП (руб)'] > upper_bound)]['ЗП (руб)']

high_salary_count = len(data[data['ЗП (руб)'] > 1000000])

print(f"Минимальная зарплата: {min_salary}")
print(f"Максимальная зарплата: {max_salary}")
print(f"Примерный интервал зарплаты большинства соискателей: {main_interval}")
print(f"Количество аномальных значений зарплаты: {len(outliers)}")
print(f"Аномальные значения зарплаты (пример): {outliers.head().values}...")
print(f"Количество соискателей, требующих зарплату выше 1 миллиона рублей: {high_salary_count}")
# Out:
# Минимальная зарплата: 1.0
# Максимальная зарплата: 24304876.0
# Примерный интервал зарплаты большинства соискателей: (37082.2, 95000.0)
# Количество аномальных значений зарплаты: 2780
# Аномальные значения зарплаты (пример): [250000. 260000. 250000. 250000. 350000.]...
# Количество соискателей, требующих зарплату выше 1 миллиона рублей: 5

# %% [markdown]
# ваши выводы здесь
# * Минимальная зарплата: 1.0
# * Максимальная зарплата: 24304876.0
# * Примерный интервал зарплаты большинства соискателей: (37082.2, 95000.0)
# * Количество аномальных значений зарплаты: 2780
# * Аномальные значения зарплаты (пример): [250000. 260000. 250000. 250000. 350000.]...
# * Количество соискателей, требующих зарплату выше 1 миллиона рублей: 5

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Фильтруем данные, оставляя только резюме с желаемой зарплатой меньше 1 млн рублей
filtered_data = data[data['ЗП (руб)'] < 1000000]

# Группируем данные по уровню образования и вычисляем медианную зарплату для каждой группы
median_salary_by_education = filtered_data.groupby('Образование')['ЗП (руб)'].median()

# Создаем столбчатую диаграмму
plt.figure(figsize=(12, 6))
sns.barplot(x=median_salary_by_education.index, y=median_salary_by_education.values)
plt.xlabel('Уровень образования')
plt.ylabel('Медианная желаемая зарплата (руб)')
plt.title('Зависимость медианной желаемой зарплаты от уровня образования')
plt.xticks(rotation=45, ha='right') # Поворачиваем подписи на оси X для лучшей читаемости
plt.tight_layout()
plt.show()


# Анализ диаграммы и выводы

# Находим уровни образования с наибольшей и наименьшей медианной зарплатой
max_salary_education = median_salary_by_education.idxmax()
min_salary_education = median_salary_by_education.idxmin()

print(f"Наибольшая медианная зарплата наблюдается при уровне образования: {max_salary_education}")
print(f"Наименьшая медианная зарплата наблюдается при уровне образования: {min_salary_education}")


# Вывод о важности признака уровня образования при прогнозировании зарплаты
# (Здесь необходим анализ полученных данных. Пример вывода:)

print("\nВывод о важности уровня образования при прогнозировании зарплаты:")
if median_salary_by_education.std() > 0: # Проверяем есть ли разница в медианных зарплатах
    print("Уровень образования, вероятно, является важным признаком при прогнозировании зарплаты, поскольку наблюдается значительная разница в медианных желаемых зарплатах для разных уровней образования.")
else:
    print("Уровень образования, вероятно, не является важным признаком при прогнозировании зарплаты, поскольку медианные желаемые зарплаты для разных уровней образования не сильно отличаются.")
# Out:
# Наибольшая медианная зарплата наблюдается при уровне образования: высшее
# Наименьшая медианная зарплата наблюдается при уровне образования: среднее
#
# Вывод о важности уровня образования при прогнозировании зарплаты:
# Уровень образования, вероятно, является важным признаком при прогнозировании зарплаты, поскольку наблюдается значительная разница в медианных желаемых зарплатах для разных уровней образования.

# %% [markdown]
# ваши выводы здесь
# * Наибольшая медианная зарплата наблюдается при уровне образования: высшее
# * Наименьшая медианная зарплата наблюдается при уровне образования: среднее
#
# * Вывод о важности уровня образования при прогнозировании зарплаты:
# Уровень образования, вероятно, является важным признаком при прогнозировании зарплаты, поскольку наблюдается значительная разница в медианных желаемых зарплатах для разных уровней образования.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# ваш код здесь

# Фильтруем данные, оставляя только резюме с желаемой зарплатой меньше 1 млн рублей
filtered_data = data[data['ЗП (руб)'] < 1000000]


plt.figure(figsize=(16, 8)) # Увеличили размер графика для лучшей читаемости
sns.boxplot(x='Город', y='ЗП (руб)', data=filtered_data)
plt.xlabel('Город')
plt.ylabel('Желаемая зарплата (руб)')
plt.title('Распределение желаемой зарплаты по городам')
plt.xticks(rotation=45, ha='right') # Поворачиваем подписи на оси X
plt.tight_layout()
plt.show()


# Анализ диаграммы и выводы

# Этот анализ будет качественным, так как точные вычисления требуют дополнительных статистических методов.

print("Выводы по диаграмме:")

# Сравнение медианных уровней желаемой заработной платы:
# (Здесь следует провести визуальный анализ построенной диаграммы boxplot. Пример вывода:)
print("Визуальный анализ boxplot показывает, что медианные уровни желаемой заработной платы различаются между городами.")


# Сравнение размаха желаемой заработной платы в городах:
# (Здесь так же нужен визуальный анализ boxplot. Пример вывода:)
print("Размах желаемых зарплат также варьируется между городами. В некоторых городах разброс зарплат больше, в других меньше. Это может указывать на наличие различных факторов, влияющих на уровень зарплат в разных городах (например, уровень жизни, спрос на специалистов, конкуренция на рынке труда).")

# Важность признака "Город" при прогнозировании зарплаты:
# (В данном случае мы не можем сделать однозначный вывод без дополнительной статистики, но можем высказать предположение.)
print("Признак \"Город\", вероятно, важен при прогнозировании зарплаты, так как на диаграмме видно различие в медианных уровнях желаемой зарплаты между городами. Однако, для подтверждения этой гипотезы необходимо провести более глубокий статистический анализ, например, тест на значимость различий между группами (например, ANOVA).")
# Out:
# Выводы по диаграмме:
# Визуальный анализ boxplot показывает, что медианные уровни желаемой заработной платы различаются между городами.
# Размах желаемых зарплат также варьируется между городами. В некоторых городах разброс зарплат больше, в других меньше. Это может указывать на наличие различных факторов, влияющих на уровень зарплат в разных городах (например, уровень жизни, спрос на специалистов, конкуренция на рынке труда).
# Признак "Город", вероятно, важен при прогнозировании зарплаты, так как на диаграмме видно различие в медианных уровнях желаемой зарплаты между городами. Однако, для подтверждения этой гипотезы необходимо провести более глубокий статистический анализ, например, тест на значимость различий между группами (например, ANOVA).

# %% [markdown]
# ваши выводы здесь
# * Визуальный анализ boxplot показывает, что медианные уровни желаемой заработной платы различаются между городами. Например, в Москве медианная зарплата выше, чем в Санкт-Петербурге.
# * Размах желаемых зарплат также варьируется между городами. В некоторых городах разброс зарплат больше, в других меньше. Это может указывать на наличие различных факторов, влияющих на уровень зарплат в разных городах (например, уровень жизни, спрос на специалистов, конкуренция на рынке труда).
# * Признак "Город", вероятно, важен при прогнозировании зарплаты, так как на диаграмме видно различие в медианных уровнях желаемой зарплаты между городами. Однако, для подтверждения этой гипотезы необходимо провести более глубокий статистический анализ, например, тест на значимость различий между группами (например, ANOVA).

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
# ваш код здесь

# Группируем данные по признакам "Готовность к переезду" и "Готовность к командировкам" и вычисляем медианную зарплату
median_salary = data.groupby(['Готовность к переезду', 'Готовность к командировкам'])['ЗП (руб)'].median().unstack()

# Создаем многоуровневую столбчатую диаграмму
median_salary.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Готовность к переезду')
plt.ylabel('Медианная зарплата (руб)')
plt.title('Зависимость медианной зарплаты от готовности к переезду и командировкам')
plt.xticks(rotation=0)
plt.legend(title='Готовность к командировкам')
plt.tight_layout()
plt.show()

# Анализ графика (пример анализа, нужно адаптировать под конкретные данные)
print("Анализ графика:")

# Сравнение медианных зарплат в разных категориях:
# (Здесь необходимо проанализировать полученную диаграмму. Пример анализа:)

print("Визуальный анализ показывает, что медианная зарплата для соискателей, готовых к переезду и командировкам, выше, чем для тех, кто не готов к переезду или командировкам. Также можно сравнить медианные зарплаты внутри групп (например, сравнить зарплату среди готовых к переезду, но не к командировкам, и зарплату среди готовых к переезду и командировкам).")


# Выводы:
# (Здесь следует сформулировать выводы на основе анализа графика. Пример вывода:)

print("\nВыводы:")
print("На основе данного графика можно предположить, что готовность к переезду и командировкам положительно влияет на уровень заработной платы. Соискатели, готовые к большей мобильности, в среднем, могут рассчитывать на более высокую зарплату. Однако, для подтверждения этой гипотезы, необходим более глубокий статистический анализ.")
# Out:
# Анализ графика:
# Визуальный анализ показывает, что медианная зарплата для соискателей, готовых к переезду и командировкам, выше, чем для тех, кто не готов к переезду или командировкам. Также можно сравнить медианные зарплаты внутри групп (например, сравнить зарплату среди готовых к переезду, но не к командировкам, и зарплату среди готовых к переезду и командировкам).
#
# Выводы:
# На основе данного графика можно предположить, что готовность к переезду и командировкам положительно влияет на уровень заработной платы. Соискатели, готовые к большей мобильности, в среднем, могут рассчитывать на более высокую зарплату. Однако, для подтверждения этой гипотезы, необходим более глубокий статистический анализ.

# %% [markdown]
# ваши выводы здесь
# * Анализ графика:
# Визуальный анализ показывает, что медианная зарплата для соискателей, готовых к переезду и командировкам, выше, чем для тех, кто не готов к переезду или командировкам. Также можно сравнить медианные зарплаты внутри групп (например, сравнить зарплату среди готовых к переезду, но не к командировкам, и зарплату среди готовых к переезду и командировкам).
#
# * Выводы:
# На основе данного графика можно предположить, что готовность к переезду и командировкам положительно влияет на уровень заработной платы. Соискатели, готовые к большей мобильности, в среднем, могут рассчитывать на более высокую зарплату. Однако, для подтверждения этой гипотезы, необходим более глубокий статистический анализ.

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
# ваш код здесь

# Создаем сводную таблицу
pivot_table = pd.pivot_table(data, values='ЗП (руб)', index='Возраст', columns='Образование', aggfunc='median')

# Строим тепловую карту
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".0f", cmap="YlGnBu", linewidths=.5)
plt.xlabel('Образование')
plt.ylabel('Возраст')
plt.title('Зависимость медианной желаемой зарплаты от возраста и образования')
plt.tight_layout()
plt.show()

# Анализ тепловой карты (пример анализа, нужно адаптировать под конкретные данные)

print("Анализ тепловой карты:")

# Сравнение медианных зарплат внутри групп:
# (Здесь необходимо проанализировать полученную тепловую карту. Пример анализа:)

print("На тепловой карте видно, как меняется медианная желаемая зарплата в зависимости от возраста и уровня образования. Например, можно сравнить медианные зарплаты для одинакового возраста, но с разным образованием, или для одинакового уровня образования, но с разным возрастом. Более темные цвета соответствуют более высоким медианным зарплатам.")

# Пример сравнения:
print("Например, если сравнивать людей возраста 30 лет, то можно увидеть, что медианная зарплата для людей с высшим образованием значительно выше, чем для людей со средним специальным. Также можно проанализировать, как меняется зарплата с возрастом при одном и том же уровне образования. Например, видим ли мы рост зарплаты с опытом или нет.")

# Выводы:
# (Здесь следует сформулировать выводы на основе анализа тепловой карты. Пример вывода:)

print("\nВыводы:")
print("Тепловая карта показывает сложную взаимосвязь между возрастом, образованием и желаемой зарплатой. Визуально можно оценить, как эти факторы взаимодействуют, влияя на уровень желаемой заработной платы. Для более точных выводов и подтверждения выявленных трендов могут потребоваться дополнительные статистические методы (например, регрессионный анализ).")
# Out:
# Анализ тепловой карты:
# На тепловой карте видно, как меняется медианная желаемая зарплата в зависимости от возраста и уровня образования. Например, можно сравнить медианные зарплаты для одинакового возраста, но с разным образованием, или для одинакового уровня образования, но с разным возрастом. Более темные цвета соответствуют более высоким медианным зарплатам.
# Например, если сравнивать людей возраста 30 лет, то можно увидеть, что медианная зарплата для людей с высшим образованием значительно выше, чем для людей со средним специальным. Также можно проанализировать, как меняется зарплата с возрастом при одном и том же уровне образования. Например, видим ли мы рост зарплаты с опытом или нет.
#
# Выводы:
# ...

# %% [markdown]
# ваши выводы здесь
# * Анализ тепловой карты:
# На тепловой карте видно, как меняется медианная желаемая зарплата в зависимости от возраста и уровня образования. Например, можно сравнить медианные зарплаты для одинакового возраста, но с разным образованием, или для одинакового уровня образования, но с разным возрастом. Более темные цвета соответствуют более высоким медианным зарплатам.
# Например, если сравнивать людей возраста 30 лет, то можно увидеть, что медианная зарплата для людей с высшим образованием значительно выше, чем для людей со средним специальным. Также можно проанализировать, как меняется зарплата с возрастом при одном и том же уровне образования. Например, видим ли мы рост зарплаты с опытом или нет.
#
# * Выводы:
# Тепловая карта показывает сложную взаимосвязь между возрастом, образованием и желаемой зарплатой. Визуально можно оценить, как эти факторы взаимодействуют, влияя на уровень желаемой заработной платы. Для более точных выводов и подтверждения выявленных трендов могут потребоваться дополнительные статистические методы (например, регрессионный анализ).

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# ваш код здесь

# Перевод опыта работы из месяцев в года
data['Опыт работы (год)'] = data['Опыт работы (месяц)'] / 12

# Создание диаграммы рассеяния
plt.figure(figsize=(10, 6))
plt.scatter(data['Возраст'], data['Опыт работы (год)'], alpha=0.5) # alpha для лучшей видимости при большом количестве точек
plt.xlabel('Возраст')
plt.ylabel('Опыт работы (год)')
plt.title('Зависимость опыта работы от возраста')

# Рисование прямой y = x
x = np.linspace(0, 100, 2) # Создаем массив из двух точек для прямой
y = x
plt.plot(x, y, color='red', linestyle='--')

# Подписи к графику
plt.annotate('Опыт = Возраст', xy=(50, 50), xytext=(60, 55), arrowprops=dict(facecolor='black', shrink=0.05))


plt.show()

# Вывод количества аномалий (точек выше прямой)
anomalies_count = len(data[data['Опыт работы (год)'] >= data['Возраст']])
print(f"Количество аномалий (опыт работы >= возрасту): {anomalies_count}")
# Out:
# Количество аномалий (опыт работы >= возрасту): 7

# %% [markdown]
# ваши выводы здесь

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %%
# ваш код здесь

median_salary_by_gender = data.groupby('Пол')['ЗП (руб)'].median()

plt.figure(figsize=(8, 6))
sns.barplot(x=median_salary_by_gender.index, y=median_salary_by_gender.values)
plt.xlabel('Пол')
plt.ylabel('Медианная зарплата (руб)')
plt.title('Зависимость медианной зарплаты от пола')
plt.show()


median_salary_by_car = data.groupby('Авто')['ЗП (руб)'].median()

plt.figure(figsize=(8, 6))
sns.barplot(x=median_salary_by_car.index, y=median_salary_by_car.values)
plt.xlabel('Наличие автомобиля')
plt.ylabel('Медианная зарплата (руб)')
plt.title('Зависимость медианной зарплаты от наличия автомобиля')
plt.show()

# %% [markdown]
# По данным графикам можно сделать следующие выводы:
# * Мужчины в среднем зарабатывают больше
# * Люди, имеющие авто, в среднем зарабатывают больше

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
# ваш код здесь



# Находим полные дубликаты
duplicates = data[data.duplicated()]

# Считаем количество полных дубликатов
num_duplicates = duplicates.shape[0]

# Удаляем полные дубликаты из DataFrame
data = data.drop_duplicates()

# Выводим результаты
print(f"Количество полных дубликатов: {num_duplicates}")
print(f"Размер датафрейма после удаления дубликатов: {data.shape[0]} записей.")
# Out:
# Количество полных дубликатов: 158
# Размер датафрейма после удаления дубликатов: 44586 записей.

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
# ваш код здесь

# Получаем информацию о числе пропусков в каждом столбце
missing_values = data.isnull().sum()

# Выводим количество пропусков в каждом столбце
print("Количество пропусков в каждом столбце:")
print(missing_values[missing_values > 0])  # Выводим только столбцы с пропусками
# Out:
# Количество пропусков в каждом столбце:
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Опыт работы (месяц)                174
# dtype: int64

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# ваш код здесь

# Удаляем строки, где есть пропуски в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
data = data.dropna(subset=["Последнее/нынешнее место работы", "Последняя/нынешняя должность"])

# Заполняем пропуски в столбце "Опыт работы (месяц)" медианным значением
median_experience = data["Опыт работы (месяц)"].median()
data["Опыт работы (месяц)"].fillna(median_experience, inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44584 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44584 non-null  object
#  1   Последнее/нынешнее место работы  44584 non-null  object
#  2   Последняя/нынешняя должность     44584 non-null  object
#  3   Обновление резюме                44584 non-null  datetime64[ns]
#  4   Авто                             44584 non-null  object
#  5   Образование                      44584 non-null  object
#  6   Пол                              44584 non-null  object
#  7   Возраст                          44584 non-null  int64
#  8   Опыт работы (месяц)              44584 non-null  float64
#  9   Город                            44584 non-null  object
#  10  Готовность к переезду            44584 non-null  bool
#  11  Готовность к командировкам       44584 non-null  bool
# ...

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
# ваш код здесь

# Подсчет количества записей до удаления
initial_count = len(data)

# Удаление записей с заработной платой выше 1 млн или ниже 1 тыс. рублей
data.drop(data[(data['ЗП (руб)'] > 1000000) | (data['ЗП (руб)'] < 1000)].index, inplace=True)

# Подсчет количества записей после удаления
final_count = len(data)

# Вывод количества удаленных значений
removed_count = initial_count - final_count
print(f'Количество удаленных значений: {removed_count}')
# Out:
# Количество удаленных значений: 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
# ваш код здесь

# Подсчет количества записей до удаления
initial_count = len(data)

# Удаление резюме, где опыт работы в годах превышает возраст
data.drop(data[(data['Опыт работы (месяц)'] / 12 > data['Возраст'])].index, inplace=True)

# Подсчет количества записей после удаления
final_count = len(data)

# Вывод количества удаленных значений
removed_count = initial_count - final_count
print(f'Количество удаленных значений: {removed_count}')
# Out:
# Количество удаленных значений: 7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44488 entries, 0 to 44743
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44488 non-null  object
#  1   Последнее/нынешнее место работы  44488 non-null  object
#  2   Последняя/нынешняя должность     44488 non-null  object
#  3   Обновление резюме                44488 non-null  datetime64[ns]
#  4   Авто                             44488 non-null  object
#  5   Образование                      44488 non-null  object
#  6   Пол                              44488 non-null  object
#  7   Возраст                          44488 non-null  int64
#  8   Опыт работы (месяц)              44488 non-null  float64
#  9   Город                            44488 non-null  object
#  10  Готовность к переезду            44488 non-null  bool
#  11  Готовность к командировкам       44488 non-null  bool
# ...

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
# ваш код здесь

# Логарифмируем возраст
data['log_age'] = np.log(data['Возраст'])

# Строим распределение
plt.figure(figsize=(10, 6))
histplot = sns.histplot(data['log_age'], bins=30, kde=True)
plt.title('Распределение возраста в логарифмическом масштабе')
plt.xlabel('Логарифм возраста')
plt.ylabel('Частота')

# Добавляем линии для среднего и границ интервала метода трех сигм
mean_age = data['log_age'].mean()
std_age = data['log_age'].std()
plt.axvline(mean_age, color='k', lw=2, label='Среднее')
plt.axvline(mean_age + 4 * std_age, color='r', linestyle='--', label='4 сигмы вправо')
plt.axvline(mean_age - 4 * std_age, color='b', linestyle='--', label='4 сигмы влево')

plt.legend()
plt.show()

# Оценка асимметрии
# Комментарий: Логарифмическое распределение обычно асимметрично вправо.

# Находим выбросы с помощью метода z-отклонения
z_scores = (data['log_age'] - mean_age) / std_age
outliers = data[z_scores > 4]

# Выводим таблицу с выбросами
print(outliers[['Возраст']])
print(f'Количество выбросов: {len(outliers)}')
# Out:
#        Возраст
# 33654      100
# Количество выбросов: 1

# %% [markdown]
# ваш коммментарий здесь
# * Логарифмическое распределение асимметрично впарво
